# %% [markdown]
# # COVID-19 analysis
#
# - <https://github.com/Kamaropoulos/covid19py>
#
# Note that the JHU data source is not providing recovery data at this time ([reference](https://github.com/ExpDev07/coronavirus-tracker-api/blob/master/README.md#recovered-cases-showing-0)).
#
# Another source of data might be the following: <https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data>
#
# ## data sources (acquired reliably from CERN)
#
# ```Bash
# virtualenv -p python3.6 COVID19
# source COVID19/bin/activate
# pip3.6 install pip --upgrade
# pip3.6 install jupyter matplotlib numpy pandas requests seaborn
# pip3.6 install COVID19Py
# python3.6
#
# import COVID19Py
# import numpy as np
# import pandas as pd
#
# import json
# import pickle
# from uuid import uuid4
#
# def uuid4_short():
#     return str(uuid4()).split('-')[0]
#
# def new_filename(ext='.pkl', verbose=True):
#     filename = uuid4_short()+ext
#     if verbose:
#         print(filename)
#     return filename
#
# #covid19 = COVID19Py.COVID19(data_source='jhu')
# #covid19 = COVID19Py.COVID19('https://coronavirus-tracker-api.herokuapp.com')
# covid19 = COVID19Py.COVID19()
# data = covid19.getAll(timelines=True)
#
# with open(new_filename(), 'wb') as f:
#     pickle.dump(covid19, f)
# with open(new_filename(), 'wb') as f:
#     pickle.dump(data, f)
# ```

# %%
import json
import pickle
from uuid import uuid4
import warnings

import COVID19Py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['axes.labelcolor'] = (1, 1, 1, 0)
pd.set_option("display.max_rows"   , 500)
pd.set_option("display.max_columns", 500)
sns.set_palette('husl')
sns.set(style='ticks')
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
plt.rcParams["figure.figsize"] = [13, 6]
sns.set()

# %%
def uuid4_short():
    return str(uuid4()).split('-')[0]
def new_filename(ext='.pkl', verbose=True):
    filename = uuid4_short()+ext
    if verbose: print(filename)
    return filename

# %%
# %%time
if 0:
    covid19 = COVID19Py.COVID19(data_source='jhu') # https://github.com/CSSEGISandData/COVID-19
    with open(new_filename(), 'wb') as f:
        pickle.dump(data, f)
    data = covid19.getAll(timelines=True)
    data
    with open(new_filename(), 'wb') as f:
        pickle.dump(data, f)
if 1:
    with open('f94e6997.pkl', 'rb') as f:
        covid19 = pickle.load(f)
    with open('120141ce.pkl', 'rb') as f:
        data = pickle.load(f)

#latest = covid19.getLatest()
#locations = covid19.getLocations(timelines=True)
# Out:
# CPU times: user 3.09 ms, sys: 0 ns, total: 3.09 ms
# Wall time: 2.77 ms

# %%
df = pd.DataFrame(data['locations'])
df.head()
#df
# Out:
#    id      country country_code  country_population province  \
# 0   0  Afghanistan           AF          29121286.0
# 1   1      Albania           AL           2986952.0
# 2   2      Algeria           DZ          34586184.0
# 3   3      Andorra           AD             84000.0
# 4   4       Angola           AO          13068161.0
#
#                   last_updated  \
# 0  2020-04-06T07:25:05.647083Z
# 1  2020-04-06T07:25:05.650175Z
# 2  2020-04-06T07:25:05.653283Z
# 3  2020-04-06T07:25:05.656321Z
# 4  2020-04-06T07:25:05.659357Z
#
#                                         coordinates  \
# 0         {'latitude': '33.0', 'longitude': '65.0'}
# 1   {'latitude': '41.1533', 'longitude': '20.1683'}
# 2    {'latitude': '28.0339', 'longitude': '1.6596'}
# 3    {'latitude': '42.5063', 'longitude': '1.5218'}
# 4  {'latitude': '-11.2027', 'longitude': '17.8739'}
#
#                                               latest  \
# 0    {'confirmed': 349, 'deaths': 7, 'recovered': 0}
# 1   {'confirmed': 361, 'deaths': 20, 'recovered': 0}
# 2  {'confirmed': 1320, 'deaths': 152, 'recovered'...
# 3   {'confirmed': 501, 'deaths': 18, 'recovered': 0}
# 4     {'confirmed': 14, 'deaths': 2, 'recovered': 0}
#
#                                            timelines
# 0  {'confirmed': {'latest': 349, 'timeline': {'20...
# 1  {'confirmed': {'latest': 361, 'timeline': {'20...
# 2  {'confirmed': {'latest': 1320, 'timeline': {'2...
# 3  {'confirmed': {'latest': 501, 'timeline': {'20...
# 4  {'confirmed': {'latest': 14, 'timeline': {'202...

# %% [markdown]
# ---

# %%
locations = {}

# %% [markdown]
# # South Korea

# %%
location_name = 'Korea, South'
location = df.query('country == @location_name')
location = location['timelines'].values[0]

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00       9887     165       NaN
# 2020-04-02 00:00:00+00:00       9976     169       NaN
# 2020-04-03 00:00:00+00:00      10062     174       NaN
# 2020-04-04 00:00:00+00:00      10156     177       NaN
# 2020-04-05 00:00:00+00:00      10237     183       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                          21.150896
# 2020-04-02 00:00:00+00:00                                          18.447524
# 2020-04-03 00:00:00+00:00                                          17.666667
# 2020-04-04 00:00:00+00:00                                          19.145034
# 2020-04-05 00:00:00+00:00                                          16.344624
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                          37.950617
# 2020-04-02 00:00:00+00:00                                          49.680808
# 2020-04-03 00:00:00+00:00                                          60.631164
# 2020-04-04 00:00:00+00:00                                          35.333333
# 2020-04-05 00:00:00+00:00                                          69.468927

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          1       0       NaN
# 1          1       0       NaN
# 2          2       0       NaN
# 3          2       0       NaN
# 4          3       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                NaN
# 1                                                NaN
# 2                                        2049.333333
# 3                                        2049.333333
# 4                                        1024.666667
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # Sweden

# %%
location_name = 'Sweden'
location = df.query('country == @location_name')
location = location['timelines'].values[0]

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00       4947     239       NaN
# 2020-04-02 00:00:00+00:00       5568     308       NaN
# 2020-04-03 00:00:00+00:00       6131     358       NaN
# 2020-04-04 00:00:00+00:00       6443     373       NaN
# 2020-04-05 00:00:00+00:00       6830     401       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                          56.829884
# 2020-04-02 00:00:00+00:00                                          61.794542
# 2020-04-03 00:00:00+00:00                                          49.774808
# 2020-04-04 00:00:00+00:00                                          25.050922
# 2020-04-05 00:00:00+00:00                                          29.568089
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                         161.354074
# 2020-04-02 00:00:00+00:00                                         142.118828
# 2020-04-03 00:00:00+00:00                                          79.913420
# 2020-04-04 00:00:00+00:00                                          20.625698
# 2020-04-05 00:00:00+00:00                                          36.952994

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          1       0       NaN
# 1          1       0       NaN
# 2          1       0       NaN
# 3          1       0       NaN
# 4          1       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                inf
# 1                                                inf
# 2                                                inf
# 3                                                inf
# 4                                                inf
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)')        ; plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # Ireland

# %%
location_name = 'Ireland'
location = df.query('country == @location_name')
location = location['timelines'].values[0] # dictionary

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']
locations[location_name] = location

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00       3447      85       NaN
# 2020-04-02 00:00:00+00:00       3849      98       NaN
# 2020-04-03 00:00:00+00:00       4273     120       NaN
# 2020-04-04 00:00:00+00:00       4604     137       NaN
# 2020-04-05 00:00:00+00:00       4994     158       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                          19.431040
# 2020-04-02 00:00:00+00:00                                          34.579542
# 2020-04-03 00:00:00+00:00                                          32.662725
# 2020-04-04 00:00:00+00:00                                          22.968338
# 2020-04-05 00:00:00+00:00                                          25.116768
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                          58.466103
# 2020-04-02 00:00:00+00:00                                          45.348078
# 2020-04-03 00:00:00+00:00                                          66.562721
# 2020-04-04 00:00:00+00:00                                          42.005111
# 2020-04-05 00:00:00+00:00                                          45.449927

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          1       0       NaN
# 1          1       0       NaN
# 2          1       0       NaN
# 3          2       0       NaN
# 4          6       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                inf
# 1                                                inf
# 2                                         296.506667
# 3                                         296.506667
# 4                                         593.013333
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # United Kingdom (approximate)

# %%
location_name = 'United Kingdom'
#location = df.query('country == @location_name')
location = df.query('country in ["United Kingdom"] and province == ""')
location = location['timelines'].values[0] # dictionary

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']
locations[location_name] = location

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00      29474    2352       NaN
# 2020-04-02 00:00:00+00:00      33718    2921       NaN
# 2020-04-03 00:00:00+00:00      38168    3605       NaN
# 2020-04-04 00:00:00+00:00      41903    4313       NaN
# 2020-04-05 00:00:00+00:00      47806    4934       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                         406.697846
# 2020-04-02 00:00:00+00:00                                         340.612414
# 2020-04-03 00:00:00+00:00                                         312.192439
# 2020-04-04 00:00:00+00:00                                         231.481016
# 2020-04-05 00:00:00+00:00                                         333.235946
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                         744.427196
# 2020-04-02 00:00:00+00:00                                         572.267557
# 2020-04-03 00:00:00+00:00                                         553.922136
# 2020-04-04 00:00:00+00:00                                         464.571074
# 2020-04-05 00:00:00+00:00                                         340.593471

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          2       0       NaN
# 1          2       0       NaN
# 2          2       0       NaN
# 3          2       0       NaN
# 4          2       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                inf
# 1                                                inf
# 2                                                inf
# 3                                                inf
# 4                                        1182.753333
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # Germany

# %%
location_name = 'Germany'
location = df.query('country == @location_name')
location = location['timelines'].values[0] # dictionary

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']
locations[location_name] = location

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00      77872     920       NaN
# 2020-04-02 00:00:00+00:00      84794    1107       NaN
# 2020-04-03 00:00:00+00:00      91159    1275       NaN
# 2020-04-04 00:00:00+00:00      96092    1444       NaN
# 2020-04-05 00:00:00+00:00     100123    1584       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                         584.825374
# 2020-04-02 00:00:00+00:00                                         615.587953
# 2020-04-03 00:00:00+00:00                                         519.844114
# 2020-04-04 00:00:00+00:00                                         374.758428
# 2020-04-05 00:00:00+00:00                                         290.512893
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                        1295.705032
# 2020-04-02 00:00:00+00:00                                        1407.646565
# 2020-04-03 00:00:00+00:00                                        1050.997073
# 2020-04-04 00:00:00+00:00                                         917.944376
# 2020-04-05 00:00:00+00:00                                         671.429917

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          1       0       NaN
# 1          4       0       NaN
# 2          4       0       NaN
# 3          4       0       NaN
# 4          5       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                inf
# 1                                           20775.96
# 2                                           20775.96
# 3                                            1731.33
# 4                                            1731.33
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # Italy

# %%
location_name = 'Italy'
location = df.query('country == @location_name')
location = location['timelines'].values[0] # dictionary

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']
locations[location_name] = location

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00     110574   13155       NaN
# 2020-04-02 00:00:00+00:00     115242   13915       NaN
# 2020-04-03 00:00:00+00:00     119827   14681       NaN
# 2020-04-04 00:00:00+00:00     124632   15362       NaN
# 2020-04-05 00:00:00+00:00     128948   15887       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                         545.530348
# 2020-04-02 00:00:00+00:00                                         509.495084
# 2020-04-03 00:00:00+00:00                                         480.165248
# 2020-04-04 00:00:00+00:00                                         483.950426
# 2020-04-05 00:00:00+00:00                                         417.940101
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                         705.984778
# 2020-04-02 00:00:00+00:00                                         697.244201
# 2020-04-03 00:00:00+00:00                                         664.366507
# 2020-04-04 00:00:00+00:00                                         559.826747
# 2020-04-05 00:00:00+00:00                                         412.452285

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          2       0       NaN
# 1          2       0       NaN
# 2          2       0       NaN
# 3          2       0       NaN
# 4          2       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                inf
# 1                                                inf
# 2                                                inf
# 3                                                inf
# 4                                        6034.373333
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# # United States of America

# %%
location_name = 'US'
location = df.query('country == @location_name')
location = location['timelines'].values[0] # dictionary

confirmed = pd.DataFrame(list(location['confirmed']['timeline'].items()), columns=['datetime', 'confirmed'])
deaths    = pd.DataFrame(list(location['deaths']['timeline'].items()),    columns=['datetime', 'deaths'])
recovered = pd.DataFrame(list(location['recovered']['timeline'].items()), columns=['datetime', 'recovered'])

confirmed.index = pd.to_datetime(confirmed['datetime']); del confirmed['datetime']
deaths.index    = pd.to_datetime(deaths['datetime'])   ; del deaths['datetime']
recovered.index = pd.to_datetime(recovered['datetime']); del recovered['datetime']

# merge
location = confirmed
location['deaths']       = deaths['deaths']
location['recovered']    = recovered['recovered']
locations[location_name] = location

# visual estimate of changes
half_mean_of_confirmed_cases = location['confirmed'].mean()/2
half_mean_of_deaths_cases    = location['confirmed'].mean()/2
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = half_mean_of_confirmed_cases*location['confirmed'].pct_change()
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = half_mean_of_confirmed_cases*location['deaths'].pct_change()
# linear interpolation
location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'] = location['confirmed_percentage_change_by_half_mean_confirmed_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location['deaths_percentage_change_by_half_mean_deaths_cases_factor']       = location['deaths_percentage_change_by_half_mean_deaths_cases_factor'].replace(0, np.nan).interpolate(method='nearest')
location.tail()
# Out:
#                            confirmed  deaths recovered  \
# datetime
# 2020-04-01 00:00:00+00:00     213372    4757       NaN
# 2020-04-02 00:00:00+00:00     243453    5926       NaN
# 2020-04-03 00:00:00+00:00     275586    7087       NaN
# 2020-04-04 00:00:00+00:00     308850    8407       NaN
# 2020-04-05 00:00:00+00:00     337072    9619       NaN
#
#                            confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# datetime
# 2020-04-01 00:00:00+00:00                                        2201.021236
# 2020-04-02 00:00:00+00:00                                        2317.040017
# 2020-04-03 00:00:00+00:00                                        2169.276124
# 2020-04-04 00:00:00+00:00                                        1983.791447
# 2020-04-05 00:00:00+00:00                                        1501.823427
#
#                            deaths_percentage_change_by_half_mean_deaths_cases_factor
# datetime
# 2020-04-01 00:00:00+00:00                                        3751.314371
# 2020-04-02 00:00:00+00:00                                        4038.871654
# 2020-04-03 00:00:00+00:00                                        3219.951019
# 2020-04-04 00:00:00+00:00                                        3061.189333
# 2020-04-05 00:00:00+00:00                                        2369.410263

# %%
# reindex to first confirmed case
location = location.query('confirmed > 0').reset_index(); del location['datetime']
location.head()
# Out:
#    confirmed  deaths recovered  \
# 0          1       0       NaN
# 1          1       0       NaN
# 2          2       0       NaN
# 3          2       0       NaN
# 4          5       0       NaN
#
#    confirmed_percentage_change_by_half_mean_confirmed_cases_factor  \
# 0                                                NaN
# 1                                                NaN
# 2                                           16435.34
# 3                                           16435.34
# 4                                           24653.01
#
#    deaths_percentage_change_by_half_mean_deaths_cases_factor
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
location.plot(title=location_name+' confirmed cases and deaths (linear scale)'); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
location.plot(title=location_name+' confirmed cases and deaths (log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %%
locations[location_name] = location

# %% [markdown]
# ---

# %%
South_Korea              = locations['Korea, South']
Sweden                   = locations['Sweden']
Ireland                  = locations['Ireland']
United_Kingdom           = locations['United Kingdom']
Germany                  = locations['Germany']
Italy                    = locations['Italy']
United_States_of_America = locations['US']

locations_list           = [South_Korea,
                            Sweden,
                            Ireland,
                            United_Kingdom,
                            Germany,
                            Italy,
                            United_States_of_America]

# %%
_df = pd.merge(South_Korea.add_suffix('_South_Korea'), Sweden.add_suffix('_Sweden'), how='inner', left_index=True, right_index=True)
_df = pd.merge(_df, Ireland.add_suffix('_Ireland'), how='inner', left_index=True, right_index=True)
_df = pd.merge(_df, United_Kingdom.add_suffix('_United_Kingdom'), how='inner', left_index=True, right_index=True)
_df = pd.merge(_df, Germany.add_suffix('_Germany'), how='inner', left_index=True, right_index=True)
_df = pd.merge(_df, Italy.add_suffix('_Italy'), how='inner', left_index=True, right_index=True)
_df = pd.merge(_df, United_States_of_America.add_suffix('_United_States_of_America'), how='inner', left_index=True, right_index=True)
_df.tail()
# Out:
#     confirmed_South_Korea  deaths_South_Korea recovered_South_Korea  \
# 32                    602                   6                   NaN
# 33                    833                   8                   NaN
# 34                    977                  10                   NaN
# 35                   1261                  12                   NaN
# 36                   1766                  13                   NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_South_Korea  \
# 32                                         799.855273
# 33                                         786.372093
# 34                                         354.266507
# 35                                         595.712044
# 36                                         820.708432
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_South_Korea  \
# 32                                        4098.666667
# 33                                         683.111111
# 34                                         512.333333
# 35                                         409.866667
# 36                                         170.777778
#
#     confirmed_Sweden  deaths_Sweden recovered_Sweden  \
# 32                21              0              NaN
# 33                35              0              NaN
# 34                94              0              NaN
# 35               101              0              NaN
# 36               161              0              NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Sweden  \
# 32                                         196.906667
# 33                                         328.177778
# 34                                         829.820952
# 35                                          36.658156
# 36                                         292.435644
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Sweden  \
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#     confirmed_Ireland  deaths_Ireland recovered_Ireland  \
# 32               3447              85               NaN
# 33               3849              98               NaN
# 34               4273             120               NaN
# 35               4604             137               NaN
# 36               4994             158               NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Ireland  \
# 32                                          19.431040
# 33                                          34.579542
# 34                                          32.662725
# 35                                          22.968338
# 36                                          25.116768
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Ireland  \
# 32                                          58.466103
# 33                                          45.348078
# 34                                          66.562721
# 35                                          42.005111
# 36                                          45.449927
#
#     confirmed_United_Kingdom  deaths_United_Kingdom recovered_United_Kingdom  \
# 32                        51                      0                      NaN
# 33                        85                      0                      NaN
# 34                       115                      1                      NaN
# 35                       163                      2                      NaN
# 36                       206                      2                      NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_Kingdom  \
# 32                                         650.514333
# 33                                        1577.004444
# 34                                         834.884706
# 35                                         987.341913
# 36                                         624.029366
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_United_Kingdom  \
# 32                                                NaN
# 33                                                NaN
# 34                                                inf
# 35                                        2365.506667
# 36                                        2365.506667
#
#     confirmed_Germany  deaths_Germany recovered_Germany  \
# 32                 48               0               NaN
# 33                 79               0               NaN
# 34                130               0               NaN
# 35                159               0               NaN
# 36                196               0               NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Germany  \
# 32                                         301.100870
# 33                                        4472.602500
# 34                                        4470.776203
# 35                                        1544.879077
# 36                                        1611.552453
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Germany  \
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#     confirmed_Italy  deaths_Italy recovered_Italy  \
# 32             2502            79             NaN
# 33             3089           107             NaN
# 34             3858           148             NaN
# 35             4636           197             NaN
# 36             5883           233             NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Italy  \
# 32                                        2762.296634
# 33                                        2831.476536
# 34                                        3004.488892
# 35                                        2433.770064
# 36                                        3246.274179
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Italy  \
# 32                                        6266.464615
# 33                                        4277.530464
# 34                                        4624.473022
# 35                                        3995.733694
# 36                                        2205.456244
#
#     confirmed_United_States_of_America  deaths_United_States_of_America  \
# 32                                  15                                0
# 33                                  51                                0
# 34                                  51                                0
# 35                                  57                                0
# 36                                  58                                0
#
#    recovered_United_States_of_America  \
# 32                                NaN
# 33                                NaN
# 34                                NaN
# 35                                NaN
# 36                                NaN
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_States_of_America  \
# 32                                       39444.816000
# 33                                       39444.816000
# 34                                       39444.816000
# 35                                        1933.569412
# 36                                         288.339298
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_United_States_of_America
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN

# %% [markdown]
# # comparisons: confirmed cases

# %%
__df = _df[[
    'confirmed_South_Korea',
    'confirmed_Sweden',
    'confirmed_Ireland',
    'confirmed_United_Kingdom',
    'confirmed_Germany',
    'confirmed_Italy',
    'confirmed_United_States_of_America']]
__df.tail()
# Out:
#     confirmed_South_Korea  confirmed_Sweden  confirmed_Ireland  \
# 32                    602                21               3447
# 33                    833                35               3849
# 34                    977                94               4273
# 35                   1261               101               4604
# 36                   1766               161               4994
#
#     confirmed_United_Kingdom  confirmed_Germany  confirmed_Italy  \
# 32                        51                 48             2502
# 33                        85                 79             3089
# 34                       115                130             3858
# 35                       163                159             4636
# 36                       206                196             5883
#
#     confirmed_United_States_of_America
# 32                                  15
# 33                                  51
# 34                                  51
# 35                                  57
# 36                                  58

# %%
title = 'comparisons: confirmed cases'
__df.plot(title=title+' '+'(linear scale)')        ; plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
__df.plot(title=title+' '+'(log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %% [markdown]
# # comparisons: deaths

# %%
__df = _df[[
    'deaths_South_Korea',
    'deaths_Sweden',
    'deaths_Ireland',
    'deaths_United_Kingdom',
    'deaths_Germany',
    'deaths_Italy',
    'deaths_United_States_of_America']]
__df.tail()
# Out:
#     deaths_South_Korea  deaths_Sweden  deaths_Ireland  deaths_United_Kingdom  \
# 32                   6              0              85                      0
# 33                   8              0              98                      0
# 34                  10              0             120                      1
# 35                  12              0             137                      2
# 36                  13              0             158                      2
#
#     deaths_Germany  deaths_Italy  deaths_United_States_of_America
# 32               0            79                                0
# 33               0           107                                0
# 34               0           148                                0
# 35               0           197                                0
# 36               0           233                                0

# %%
title = 'comparisons: deaths'
__df.plot(title=title+' '+'(linear scale)')        ; plt.xlabel('days since first confirmed case'); plt.ylabel('cases');
__df.plot(title=title+' '+'(log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('cases');

# %% [markdown]
# # comparisons: changes in confirmed cases

# %%
__df = _df[[
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_South_Korea',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Sweden',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Ireland',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_Kingdom',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Germany',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Italy',
    'confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_States_of_America']]
__df.tail()
# Out:
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_South_Korea  \
# 32                                         799.855273
# 33                                         786.372093
# 34                                         354.266507
# 35                                         595.712044
# 36                                         820.708432
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Sweden  \
# 32                                         196.906667
# 33                                         328.177778
# 34                                         829.820952
# 35                                          36.658156
# 36                                         292.435644
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Ireland  \
# 32                                          19.431040
# 33                                          34.579542
# 34                                          32.662725
# 35                                          22.968338
# 36                                          25.116768
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_Kingdom  \
# 32                                         650.514333
# 33                                        1577.004444
# 34                                         834.884706
# 35                                         987.341913
# 36                                         624.029366
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Germany  \
# 32                                         301.100870
# 33                                        4472.602500
# 34                                        4470.776203
# 35                                        1544.879077
# 36                                        1611.552453
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_Italy  \
# 32                                        2762.296634
# 33                                        2831.476536
# 34                                        3004.488892
# 35                                        2433.770064
# 36                                        3246.274179
#
#     confirmed_percentage_change_by_half_mean_confirmed_cases_factor_United_States_of_America
# 32                                       39444.816000
# 33                                       39444.816000
# 34                                       39444.816000
# 35                                        1933.569412
# 36                                         288.339298

# %%
title = 'comparisons: changes in confirmed cases'
__df.plot(title=title+' '+'(linear scale)')        ; plt.xlabel('days since first confirmed case'); plt.ylabel('arbitrary scale');
__df.plot(title=title+' '+'(log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('arbitrary scale');

# %%
___df = _df[[
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_South_Korea',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_Sweden',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_Ireland',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_United_Kingdom',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_Germany',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_Italy',
    'deaths_percentage_change_by_half_mean_deaths_cases_factor_United_States_of_America']]
___df.tail()
# Out:
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_South_Korea  \
# 32                                        4098.666667
# 33                                         683.111111
# 34                                         512.333333
# 35                                         409.866667
# 36                                         170.777778
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Sweden  \
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Ireland  \
# 32                                          58.466103
# 33                                          45.348078
# 34                                          66.562721
# 35                                          42.005111
# 36                                          45.449927
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_United_Kingdom  \
# 32                                                NaN
# 33                                                NaN
# 34                                                inf
# 35                                        2365.506667
# 36                                        2365.506667
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Germany  \
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_Italy  \
# 32                                        6266.464615
# 33                                        4277.530464
# 34                                        4624.473022
# 35                                        3995.733694
# 36                                        2205.456244
#
#     deaths_percentage_change_by_half_mean_deaths_cases_factor_United_States_of_America
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN

# %%
title = 'comparisons: changes in deaths'
__df.plot(title=title+' '+'(linear scale)')        ; plt.xlabel('days since first confirmed case'); plt.ylabel('arbitrary scale');
__df.plot(title=title+' '+'(log scale)', logy=True); plt.xlabel('days since first confirmed case'); plt.ylabel('arbitrary scale');
